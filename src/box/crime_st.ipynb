# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("crcCASt.csv")
#data source = "https://data.gov.in/resource/crime-against-schedule-tribe-during-2001-2012"

# %%
d=pd.re

# %%
data
# Out:
#               STATE/UT                CRIME HEAD  2001  2002  2003  2004  \
# 0       Andhra Pradesh             MURDER OF STs     4     2     9    10
# 1    Arunachal Pradesh             MURDER OF STs     4     2     0     2
# 2                Assam             MURDER OF STs     0     6     2     1
# 3                Bihar             MURDER OF STs     1     5     3     0
# 4         Chhattisgarh             MURDER OF STs    18    12    13    32
# ..                 ...                       ...   ...   ...   ...   ...
# 413              Delhi  TOTAL CRIMES AGAINST STs     0     0     0     0
# 414        Lakshadweep  TOTAL CRIMES AGAINST STs     0     1     0     0
# 415         Puducherry  TOTAL CRIMES AGAINST STs     0     0     0     0
# 416        Total (UTs)  TOTAL CRIMES AGAINST STs     7     5    25     6
# 417  TOTAL (ALL-INDIA)  TOTAL CRIMES AGAINST STs  6217  6774  5889  5535
#
#      2005  2006  2007  2008  2009  2010  2011  2012
# ...

# %%
cur_data1=data[data["CRIME HEAD"]=="TOTAL CRIMES AGAINST STs"].loc[380:407,:]

# %%
cols=list(cur_data1.columns)
cols.remove('CRIME HEAD')

# %%
cur_data=cur_data1[cols]

# %%
cur_data
# Out:
#               STATE/UT  2001  2002  2003  2004  2005  2006  2007  2008  2009  \
# 380     Andhra Pradesh   512   525   571   566   515   793   753   750   830
# 381  Arunachal Pradesh    72    87    66    75    54    27    32    63    21
# 382              Assam     0    39    20    12   216   244    49   130     9
# 383              Bihar    47    29    52    45    82    56    65    99    67
# 384       Chhattisgarh   486   508   774   676   497   583   615   424   376
# 385                Goa     0     0     0     0     1     0     0     1     0
# 386            Gujarat   309   340   241   241   237   164   156   223   195
# 387            Haryana     0     5     0     0     0     0     0     0     0
# 388   Himachal Pradesh     4     3    12    11    10    17     2     0     1
# 389    Jammu & Kashmir     0     6     1     1     0     0     0     0     0
# 390          Jharkhand   282   124   108   123   483   332   268   231   182
# ...

# %%
tcur=cur_data.set_index("STATE/UT").T

# %%
tcur.boxplot()
plt.xticks(rotation=90)
plt.tick_params(axis='x', which='major', labelsize=8)
plt.tight_layout()
plt.title("Total crimes against STs in the years 2001-2012 among states",)
plt.savefig("bx.png",format='png',bbox_inches='tight',dpi=300)
plt.show()
